# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '1.4.2'

# %%
# !pip install pyarrow

# %%
df_jun = pd.read_parquet('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2023-01.parquet')

# %%
df_feb = pd.read_parquet('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2023-02.parquet')

# %%
df_jun.shape
# Out:
# (3066766, 19)

# %%
total_df = pd.concat([df_jun, df_feb], axis=0)

# %%
assert len(total_df.columns) == len(df_jun.columns) == len(df_feb.columns) , 'Не та ось ( посмотри на axis )'
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Input In [11], in <cell line: 1>()
# ----> 1 assert len(total_df.columns) == len(df_jun.columns) == len(df_feb.columns) , 'Не та ось ( посмотри на axis )'
#
# AssertionError: Не та ось ( посмотри на axis )

# %%
print(len(total_df.columns))
# Out:
# 20

# %%
import sklearn

# %%
sklearn.__version__
# Out:
# '1.0.2'

# %%
total_df.head(1)
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2023-01-01 00:32:10   2023-01-01 00:40:36              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           0.97         1.0                  N           161           141
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0             2          9.3    1.0      0.5         0.0           0.0
#
#    improvement_surcharge  total_amount  congestion_surcharge  airport_fee  \
# 0                    1.0          14.3                   2.5          0.0
#
#    Airport_fee
# 0          NaN

# %%
total_df['duration'] = (total_df['tpep_dropoff_datetime'] - total_df['tpep_pickup_datetime']).dt.total_seconds() / 60

# %%
total_df = total_df.drop(['tpep_dropoff_datetime','tpep_pickup_datetime'],axis=1)

# %%
total_df['duration'].std()
# Out:
# 42.71558930076808

# %%
total_df['duration'].dtype
# Out:
# dtype('float64')

# %%
mask = ((total_df['duration'] <= 60) & (total_df['duration'] >= 1))

# %%
# total_df = total_df.loc[mask] падает ядро из-за того, что не хватает RAM}

# %%
total_df = total_df.query('1 <= duration <= 60')

# %%
total_df.shape[0]
# Out:
# 5865124

# %%
total_df.shape[0]
# Out:
# 5865124

# %%
5865124/5980721
# Out:
# 0.9806717283752243

# %%
total_df.head(5)
# Out:
#    VendorID  passenger_count  trip_distance  RatecodeID store_and_fwd_flag  \
# 0         2              1.0           0.97         1.0                  N
# 1         2              1.0           1.10         1.0                  N
# 2         2              1.0           2.51         1.0                  N
# 3         1              0.0           1.90         1.0                  N
# 4         2              1.0           1.43         1.0                  N
#
#    PULocationID  DOLocationID  payment_type  fare_amount  extra  mta_tax  \
# 0           161           141             2          9.3   1.00      0.5
# 1            43           237             1          7.9   1.00      0.5
# 2            48           238             1         14.9   1.00      0.5
# 3           138             7             1         12.1   7.25      0.5
# 4           107            79             1         11.4   1.00      0.5
#
#    tip_amount  tolls_amount  improvement_surcharge  total_amount  \
# ...

# %%
total_df.dtypes
# Out:
# VendorID                   int64
# passenger_count          float64
# trip_distance            float64
# RatecodeID               float64
# store_and_fwd_flag        object
# PULocationID               int64
# DOLocationID               int64
# payment_type               int64
# fare_amount              float64
# extra                    float64
# mta_tax                  float64
# tip_amount               float64
# tolls_amount             float64
# improvement_surcharge    float64
# total_amount             float64
# congestion_surcharge     float64
# airport_fee              float64
# Airport_fee              float64
# duration                 float64
# dtype: object

# %%
total_df['store_and_fwd_flag']
# Out:
# 0             N
# 1             N
# 2             N
# 3             N
# 4             N
#            ...
# 2913950    None
# 2913951    None
# 2913952    None
# 2913953    None
# 2913954    None
# Name: store_and_fwd_flag, Length: 5865124, dtype: object

# %%
total_df.isna().sum()
# Out:
# VendorID                       0
# passenger_count           146254
# trip_distance                  0
# RatecodeID                146254
# store_and_fwd_flag        146254
# PULocationID                   0
# DOLocationID                   0
# payment_type                   0
# fare_amount                    0
# extra                          0
# mta_tax                        0
# tip_amount                     0
# tolls_amount                   0
# improvement_surcharge          0
# total_amount                   0
# congestion_surcharge      146254
# airport_fee              2927056
# Airport_fee              3084322
# duration                       0
# dtype: int64

# %%
total_df['airport_fee'] = total_df['airport_fee'].fillna(0.0)

# %%
total_df['Airport_fee'] = total_df['Airport_fee'].fillna(0.0)
